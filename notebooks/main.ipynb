# %%
import os
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
# Out:
# c:\Users\Owent\Desktop\Projects\community\notebooks
# c:\Users\Owent\Desktop\Projects\community

# %%
from src.graph import Node, Edge, Graph

n1 = Node(1)
n2 = Node(2)
n3 = Node(3)
n4 = Node(4)
n5 = Node(5)
n6 = Node(6)

e1 = Edge(n1, n2, 3)
e2 = Edge(n2, n3, 5)
e3 = Edge(n3, n4, 1)
e4 = Edge(n4, n5, 8)
e5 = Edge(n5, n6, 2)
e6 = Edge(n4, n6, 9)

nodes = [n1, n2, n3, n4, n5, n6]
edges = [e1, e2, e3, e4, e5, e6]
graph = Graph(nodes=nodes, edges=edges)

# %%
graph
# Out:
# Graph(nodes=[Node(id=1), Node(id=2), Node(id=3), Node(id=4), Node(id=5), Node(id=6)], edges=[Edge(node1=Node(id=1), node2=Node(id=2), weight=3), Edge(node1=Node(id=2), node2=Node(id=3), weight=5), Edge(node1=Node(id=3), node2=Node(id=4), weight=1), Edge(node1=Node(id=4), node2=Node(id=5), weight=8), Edge(node1=Node(id=5), node2=Node(id=6), weight=2), Edge(node1=Node(id=4), node2=Node(id=6), weight=9)])

# %%
from src.graph.algorithms import louvain

new_c_mapping = louvain(graph)
# Out:
# 2026-04-21 22:58:41.389 | INFO     | src.graph.algorithms:louvain:161 - Started 1 iteration...
# 2026-04-21 22:58:41.390 | INFO     | src.graph.algorithms:louvain:170 - Old Community Mapping: {Node(id=1): Node(id=1), Node(id=2): Node(id=2), Node(id=3): Node(id=3), Node(id=4): Node(id=4), Node(id=5): Node(id=5), Node(id=6): Node(id=6)}
# 2026-04-21 22:58:41.391 | INFO     | src.graph.algorithms:louvain:171 - New Community Mapping: {Node(id=1): Node(id=1), Node(id=2): Node(id=3), Node(id=3): Node(id=3), Node(id=4): Node(id=4), Node(id=5): Node(id=5), Node(id=6): Node(id=4)}
# 2026-04-21 22:58:41.391 | INFO     | src.graph.algorithms:louvain:173 - Started 2 iteration...
# 2026-04-21 22:58:41.393 | INFO     | src.graph.algorithms:louvain:170 - Old Community Mapping: {Node(id=1): Node(id=1), Node(id=2): Node(id=3), Node(id=3): Node(id=3), Node(id=4): Node(id=4), Node(id=5): Node(id=5), Node(id=6): Node(id=4)}
# ...

# %%
new_c_mapping
# Out:
# {Node(id=1): Node(id=1),
#  Node(id=2): Node(id=1),
#  Node(id=3): Node(id=1),
#  Node(id=4): Node(id=4),
#  Node(id=5): Node(id=4),
#  Node(id=6): Node(id=4)}
