# %%
import os
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
# Out:
# c:\Users\Owent\Desktop\Projects\community\notebooks
# c:\Users\Owent\Desktop\Projects\community

# %%
from src.graph import Node, Edge, Graph

n1 = Node(1)
n2 = Node(2)
n3 = Node(3)

e1 = Edge(n1, n2, 3)
e2 = Edge(n2, n3, 5)

nodes = [n1, n2, n3]
edges = [e1, e2]
graph = Graph(nodes=nodes, edges=edges)

# %%
graph
# Out:
# Graph(nodes=[Node(id=1), Node(id=2), Node(id=3)], edges=[Edge(node1=Node(id=1), node2=Node(id=2), weight=3), Edge(node1=Node(id=2), node2=Node(id=3), weight=5)])
